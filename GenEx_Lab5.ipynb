# %%
library(data.table)
library(dplyr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b58c275c8680> in <module>
# ----> 1 library(data.table)
#       2 library(dplyr)
#
# NameError: name 'library' is not defined
